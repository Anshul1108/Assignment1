# %%
fruit=["mango","apple","banana"]
print(fruit)
#Update
fruit[2]="grapes"
print(fruit)
#Append
fruit.append("orange")
print(fruit)
#Insert
fruit.insert(1,"kiwi")
print(fruit)
#Delete
fruit.remove("apple")
print(fruit)
#Indexing
print(fruit[0])
# Out:
# ['mango', 'apple', 'banana']
# ['mango', 'apple', 'grapes']
# ['mango', 'apple', 'grapes', 'orange']
# ['mango', 'kiwi', 'apple', 'grapes', 'orange']
# ['mango', 'kiwi', 'grapes', 'orange']
# mango
